# %%
import cv2
import os
import random
import numpy as np

# %%
mydir='train'

# %%
categories=['cat','dog']

# %%
data=[]
for i in categories:
    folder_path=os.path.join(mydir,i)

    if i=='cat':
        label=0
    else:
        label=1

    for j in os.listdir(folder_path):
        img_path=os.path.loin(folder_path,j)

        img=cv2.imread(img_path)
        img=cv2.resize(img,(150,150))
        data.append([img,label])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 11
#       8     label=1
#      10 for j in os.listdir(folder_path):
# ---> 11     img_path=os.path.loin(folder_path,j)
#      13     img=cv2.imread(img_path)
#      14     img=cv2.resize(img,(150,150))
#
# AttributeError: module 'posixpath' has no attribute 'loin'

# %%
random.shuffle(data)

# %%
X=[]
y=[]

for i in data :
    X.append(i[0])
    y.append(i[1])

# %%
X=np.array(X)
y=np.array(y)

# %%
X.shape
# Out:
# (0,)

# %%
# %%
import cv2
import os
import random
import numpy as np

# %%
mydir = 'train'

# %%
categories = ['cat', 'dog']

# %%
data = []
for i in categories:
    folder_path = os.path.join(mydir, i)

    # Assign labels based on category
    label = 0 if i == 'cat' else 1

    for j in os.listdir(folder_path):
        img_path = os.path.join(folder_path, j)  # Corrected typo here

        img = cv2.imread(img_path)
        if img is not None:  # Ensure the image is read successfully
            img = cv2.resize(img, (150, 150))
            data.append([img, label])

# %%
random.shuffle(data)

# %%
X = []
y = []

for i in data:
    X.append(i[0])
    y.append(i[1])

# %%
X = np.array(X)
y = np.array(y)

# Check the shape of the data
x
# Out:
# (1593, 150, 150, 3)

# %%
X.shape
# Out:
# (1593, 150, 150, 3)

# %%
y.shape
# Out:
# (1593,)

# %%
"/workspaces/CNN/4.data augmentation/1.using keras library(ImageDataGeneraotr class)/2.generating from multiple images/1.performance of model without using agumented image/train/cat/cat.0.jpg"

# %%
import os

def count_files_in_folder(folder_path):
    try:
        # List all entries in the directory
        entries = os.listdir(folder_path)
        # Filter only files
        files = [entry for entry in entries if os.path.isfile(os.path.join(folder_path, entry))]
        return len(files)
    except Exception as e:
        print(f"An error occurred: {e}")
        return 0

# Folder name is 'train'
folder_path = "train"  # Replace with the full path if not in the current directory
file_count = count_files_in_folder(folder_path)
print(f"The 'train' folder contains {file_count} files.")
# Out:
# The 'train' folder contains 0 files.

# %%
import os

# Get the current working directory
cwd = os.getcwd()
print(f"Current Working Directory: {cwd}")
# Out:
# Current Working Directory: /workspaces/CNN/4.data augmentation/1.using keras library(ImageDataGeneraotr class)/2.generating from multiple images/1.performance of model without using agumented image
