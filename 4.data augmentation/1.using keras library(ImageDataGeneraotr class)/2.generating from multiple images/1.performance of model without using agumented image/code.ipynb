# %%
import cv2
import os
import random
import numpy as np

# %%
mdir='train'

# %%
categories=['cat','dog']

# %%
for i in categories:
    folder_path=os.path.join(mydir,i)
# Out:
#   Cell In[8], line 2
#
#     ^
# SyntaxError: incomplete input
